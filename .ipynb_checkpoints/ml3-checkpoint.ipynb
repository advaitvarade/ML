# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns;
from sklearn.preprocessing import Binarizer
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.read_csv("Admission_Predict_Ver1.1.csv")

# %%
df.shape
# Out:
# (500, 9)

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
bi=Binarizer(threshold=0.75)
df['Chance of Admit ']=bi.fit_transform(df[['Chance of Admit ']])

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1               1.0
# 1         1               1.0
# 2         1               0.0
# 3         1               1.0
# 4         0               0.0

# %%
x=df.drop('Chance of Admit ',axis=1)
y=df['Chance of Admit ']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, random_state=0, train_size=0.75)

# %%
model = DecisionTreeClassifier(random_state=0)
model.fit(x_train, y_train)
y_pred= model.predict(x_test)
from sklearn.metrics import classification_report,accuracy_score

# %%
accuracy_score(y_test,y_pred)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97        81
#          1.0       0.95      0.93      0.94        44
#
#     accuracy                           0.96       125
#    macro avg       0.96      0.95      0.96       125
# weighted avg       0.96      0.96      0.96       125

# %%
from sklearn.metrics import classification_report
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(30,30))
print(plot_tree(model, fontsize=8, filled= True,feature_names=x.columns,class_names=["yes","no"]))
# Out:
# [Text(0.5288461538461539, 0.9583333333333334, 'CGPA <= 8.735\ngini = 0.493\nsamples = 375\nvalue = [209, 166]\nclass = yes'), Text(0.2564102564102564, 0.875, 'GRE Score <= 318.5\ngini = 0.211\nsamples = 217\nvalue = [191, 26]\nclass = yes'), Text(0.3926282051282051, 0.9166666666666667, 'True  '), Text(0.14102564102564102, 0.7916666666666666, 'CGPA <= 8.25\ngini = 0.103\nsamples = 183\nvalue = [173, 10]\nclass = yes'), Text(0.11538461538461539, 0.7083333333333334, 'gini = 0.0\nsamples = 105\nvalue = [105, 0]\nclass = yes'), Text(0.16666666666666666, 0.7083333333333334, 'SOP <= 4.75\ngini = 0.224\nsamples = 78\nvalue = [68, 10]\nclass = yes'), Text(0.10256410256410256, 0.625, 'TOEFL Score <= 99.5\ngini = 0.191\nsamples = 75\nvalue = [67, 8]\nclass = yes'), Text(0.05128205128205128, 0.5416666666666666, 'Serial No. <= 361.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = yes'), Text(0.02564102564102564, 0.4583333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = no'), Text(0.07692307692307693, 0.4583333333333333, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = yes'), Text(0.15384615384615385, 0.5416666666666666, 'TOEFL Score <= 105.5\ngini = 0.157\nsamples = 70\nvalue = [64, 6]\nclass = yes'), Text(0.1282051282051282, 0.4583333333333333, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]\nclass = yes'), Text(0.1794871794871795, 0.4583333333333333, 'GRE Score <= 311.5\ngini = 0.272\nsamples = 37\nvalue = [31, 6]\nclass = yes'), Text(0.1282051282051282, 0.375, 'GRE Score <= 306.5\ngini = 0.459\nsamples = 14\nvalue = [9, 5]\nclass = yes'), Text(0.10256410256410256, 0.2916666666666667, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = yes'), Text(0.15384615384615385, 0.2916666666666667, 'LOR  <= 2.75\ngini = 0.494\nsamples = 9\nvalue = [4, 5]\nclass = no'), Text(0.1282051282051282, 0.20833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = yes'), Text(0.1794871794871795, 0.20833333333333334, 'TOEFL Score <= 108.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = no'), Text(0.15384615384615385, 0.125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = no'), Text(0.20512820512820512, 0.125, 'SOP <= 3.75\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = yes'), Text(0.1794871794871795, 0.041666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = yes'), Text(0.23076923076923078, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = no'), Text(0.23076923076923078, 0.375, 'CGPA <= 8.675\ngini = 0.083\nsamples = 23\nvalue = [22, 1]\nclass = yes'), Text(0.20512820512820512, 0.2916666666666667, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = yes'), Text(0.2564102564102564, 0.2916666666666667, 'SOP <= 3.75\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = yes'), Text(0.23076923076923078, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = no'), Text(0.28205128205128205, 0.20833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = yes'), Text(0.23076923076923078, 0.625, 'Serial No. <= 121.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = no'), Text(0.20512820512820512, 0.5416666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = yes'), Text(0.2564102564102564, 0.5416666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = no'), Text(0.3717948717948718, 0.7916666666666666, 'CGPA <= 8.405\ngini = 0.498\nsamples = 34\nvalue = [18, 16]\nclass = yes'), Text(0.3076923076923077, 0.7083333333333334, 'TOEFL Score <= 114.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = yes'), Text(0.28205128205128205, 0.625, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = yes'), Text(0.3333333333333333, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = no'), Text(0.4358974358974359, 0.7083333333333334, 'Serial No. <= 356.0\ngini = 0.48\nsamples = 25\nvalue = [10, 15]\nclass = no'), Text(0.38461538461538464, 0.625, 'CGPA <= 8.63\ngini = 0.492\nsamples = 16\nvalue = [9, 7]\nclass = yes'), Text(0.358974358974359, 0.5416666666666666, 'gini = 0.0\nsamples = 6\ ...

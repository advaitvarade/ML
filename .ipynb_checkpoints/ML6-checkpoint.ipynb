# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules

# %%
dataset = []
with open("Market_Basket_Optimisation.csv") as file:
    reader =csv.reader(file , delimiter = ',')
    for row in reader:
        dataset +=[row]

# %%
te = TransactionEncoder()
x = te.fit_transform(dataset)

# %%
x
# Out:
# array([[False,  True,  True, ...,  True, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]], shape=(7501, 120))

# %%
df = pd.DataFrame(x, columns = te.columns_)

# %%
df.head()
# Out:
# Series([], Name: avocado, dtype: bool)

# %%
a_itemset = apriori(df,min_support=0.01,use_colnames=True)

# %%
a_itemset
# Out:
#       support                                 itemsets
# 0    0.020397                                (almonds)
# 1    0.033329                                (avocado)
# 2    0.010799                         (barbecue sauce)
# 3    0.014265                              (black tea)
# 4    0.011465                             (body spray)
# ..        ...                                      ...
# 252  0.011065       (milk, mineral water, ground beef)
# 253  0.017064  (ground beef, mineral water, spaghetti)
# 254  0.015731         (milk, mineral water, spaghetti)
# 255  0.010265    (mineral water, olive oil, spaghetti)
# 256  0.011465     (mineral water, pancakes, spaghetti)
#
# [257 rows x 2 columns]

# %%
rules = association_rules(a_itemset, metric = 'confidence', min_threshold=0.25)

# %%
rules
# Out:
#                    antecedents      consequents  antecedent support  \
# 0                    (avocado)  (mineral water)            0.033329
# 1                    (burgers)           (eggs)            0.087188
# 2                    (burgers)   (french fries)            0.087188
# 3                    (burgers)  (mineral water)            0.087188
# 4                       (cake)  (mineral water)            0.081056
# ..                         ...              ...                 ...
# 90  (mineral water, spaghetti)           (milk)            0.059725
# 91  (mineral water, olive oil)      (spaghetti)            0.027596
# 92      (olive oil, spaghetti)  (mineral water)            0.022930
# 93   (mineral water, pancakes)      (spaghetti)            0.033729
# 94       (pancakes, spaghetti)  (mineral water)            0.025197
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.238368  0.011598    0.348000  1.459926               1.0
# ...

# %%
rules[rules['antecedents']=={'cake'}]['consequents']
# Out:
# 4    (mineral water)
# Name: consequents, dtype: object
